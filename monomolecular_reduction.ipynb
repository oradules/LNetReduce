# %%
import networkx as nx
import lnetreduce

# %%
filename = "models/prisme.csv"
reduced_filename = "%s_reduced" % filename
timescale = 8

# %%
G = lnetreduce.load_graph(filename)
pos = nx.nx_pydot.graphviz_layout(G)
nx.draw(G, pos)

# %%
X = lnetreduce.simulate_and_plot(G, timescale)

# %%
uG = lnetreduce.reduce_graph(G)
nx.draw(uG, pos)
# Out:
# ungluing: {3: OutEdgeDataView([(3, 1, 15), (1, 3, 7)])}
#     3 (lim:3)   [(1, 3, 7)]
#     Restore incoming edges [] []
#     Ready to unglue: [3] [(1, 3, 7)]
# ungluing: {3: OutEdgeDataView([(3, 4, 9), (4, 5, 5), (5, 3, 2)]), 1: OutEdgeDataView([(0, 1, 1), (1, 2, 6), (2, 0, 4)])}
#     3 (lim:3)   [(4, 5, 5), (5, 3, 2)]
#     Restore incoming edges [(1, 3, 7)] [(0, 3, 3), (1, 4, 7), (2, 5, 10)]
#     1 (lim:1)   [(4, 5, 5), (5, 3, 2), (1, 4, 7), (0, 1, 1), (2, 0, 4)]
#     Restore incoming edges [] [(3, 2, 15)]
#     Ready to unglue: [3, 1] [(4, 5, 5), (5, 3, 2), (1, 4, 7), (0, 1, 1), (2, 0, 4)]

# %%
X = lnetreduce.simulate_and_plot(uG, timescale)
