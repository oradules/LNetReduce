# %%
import networkx as nx
import lnetreduce

# %%
filename = "models/prisme.csv"
timescale = 8

# %%
G = lnetreduce.load_graph(filename)
pos = nx.nx_pydot.graphviz_layout(G)
nx.draw(G, pos)

# %%
X = lnetreduce.simulate_and_plot(G, timescale)

# %%
uG = lnetreduce.reduce_graph(G)
nx.draw(uG, pos)
# Out:
# ungluing: {'A3': OutEdgeDataView([('A3', 'A1', 15), ('A1', 'A3', 7)])}
#     A3 (lim:A3)   [('A1', 'A3', 7)]
#     Restore incoming edges [] []
#     Ready to unglue: ['A3'] [('A1', 'A3', 7)]
# ungluing: {'A3': OutEdgeDataView([('A3', 'A4', 9), ('A4', 'A5', 5), ('A5', 'A3', 2)]), 'A1': OutEdgeDataView([('A0', 'A1', 1), ('A1', 'A2', 6), ('A2', 'A0', 4)])}
#     A3 (lim:A3)   [('A4', 'A5', 5), ('A5', 'A3', 2)]
#     Restore incoming edges [('A1', 'A3', 7)] [('A0', 'A3', 3), ('A1', 'A4', 7), ('A2', 'A5', 10)]
#     A1 (lim:A1)   [('A4', 'A5', 5), ('A5', 'A3', 2), ('A1', 'A4', 7), ('A0', 'A1', 1), ('A2', 'A0', 4)]
#     Restore incoming edges [] [('A3', 'A2', 15)]
#     Ready to unglue: ['A3', 'A1'] [('A4', 'A5', 5), ('A5', 'A3', 2), ('A1', 'A4', 7), ('A0', 'A1', 1), ('A2', 'A0', 4)]

# %%
X = lnetreduce.simulate_and_plot(uG, timescale)
