# %%
import lnetreduce

# %%
filename = "models/flower_CMSB_ERR.csv"
timescale = 10

# %%
G = lnetreduce.load_graph(filename)
pos = lnetreduce.plot_graph(G)

# %%
sol = lnetreduce.simulate(G,timescale)

# %%
lnetreduce.simulate_and_plot(G, timescale)

# %%
uG = lnetreduce.reduce_graph(G)
# Out:
# ---------------------------------------------------------------------------
# DuplicateMinError                         Traceback (most recent call last)
# <ipython-input-6-93839382bdb2> in <module>
# ----> 1 uG = lnetreduce.reduce_graph(G)
#
# ~/git/ext/LNetReduce/lnetreduce/reduction.py in reduce_graph(G, debug, partial)
#     277
#     278 def reduce_graph( G, debug=False, partial=False ):
# --> 279     return unglue_stack( glue(G, debug=debug, partial=partial), debug=debug )
#     280
#     281
#
# ~/git/ext/LNetReduce/lnetreduce/reduction.py in glue(G, debug, partial)
#     145         restored_i = restore_cycles_out_edges( g_i, pruned_i )
#     146         try:
# --> 147             L.append( glue_graph( pruned_i, restored_i, debug=debug, partial=partial ) )
#     148         except:
#     149             if not partial: raise
#
# ~/git/ext/LNetReduce/lnetreduce/reduction.py in glue_graph(pruned_G, restored_G, debug, partial)
#     127     cycles_list = list( nx.simple_cycles(pruned_G) )
#     128     for cycle in cycles_list:
# --> 129         glued_G = glue_cycle( pruned_G, glued_G, cycle, debug )
#     130     return glued_G
#     131
#
# ~/git/ext/LNetReduce/lnetreduce/reduction.py in glue_cycle(pruned_G, restored_G, cycle, debug)
#      94     #and redirect the in edges
#      95     lim_step = max( cycle_edges, key=lambda x:x[2] )
# ---> 96     check_unique(cycle_edges, lim_step[2], debug)
#      97     out_edges = select_unique_edges( renorm( cycle_edges, out_list, lim_step ) )
#      98     in_edges = select_unique_edges( redirect( in_list, lim_step[0] ) )
#
# ~/git/ext/LNetReduce/lnetreduce/reduction.py in check_unique(edges, best, debug)
#     321                 if debug:
#     322                     print("Duplicated best edge")
# --> 323                 raise DuplicateMinError((best,edges))
#     324             count += 1
#     325
#
# DuplicateMinError: (15, OutEdgeDataView([(2, 3, 15), (3, 2, 15)]))

# %%
uG = lnetreduce.reduce_graph(G, partial=True)
_ = lnetreduce.plot_graph(uG, layout=pos)
# Out:
# Failed to glue one cycle

# %%
lnetreduce.simulate_and_plot(uG, timescale)
